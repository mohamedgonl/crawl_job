# %%
import pandas as pd

# %%
df = pd.read_json('./data.json')
df
# Out:
#                                    job_type
# 0      Agriculture, Fishing & Forestry Jobs  \
# 1          PR, Advertising & Marketing Jobs
# 2          PR, Advertising & Marketing Jobs
# 3          PR, Advertising & Marketing Jobs
# 4          PR, Advertising & Marketing Jobs
# ...                                     ...
# 77766             Healthcare & Nursing Jobs
# 77767             Healthcare & Nursing Jobs
# 77768             Healthcare & Nursing Jobs
# 77769             Healthcare & Nursing Jobs
# 77770             Healthcare & Nursing Jobs
#
#                                                 job_name posting_date:
# 0                          Harvest Temp - Site Operative   19 May 2023  \
# 1                        FIELD MARKETING – SELF EMPLOYED   22 May 2023
# 2                        FIELD MARKETING – SELF EMPLOYED   22 May 2023
# 3                        FIELD MARKETING – SELF EMPLOYED   22 May 2023
# 4                        FIELD MARKETING – SELF EMPLOYED   22 May 2023
# ...

# %%
df.describe()
# Out:
#                   job_type        job_name posting_date:     hours:
# count                77771           77771         77771      77771  \
# unique                  25           37606            31          2
# top     Other/General Jobs  Support Worker   12 May 2023  Full time
# freq                 14735            1071          5948      58799
#
#        closing_date:   location:  company:  job_type: job_reference:
# count          77771       77771     77771      77771          77771  \
# unique            60       33587      4207          4          65846
# top      26 May 2023  London, UK  NHS Jobs  Permanent
# freq            4393         308      7464      56904           9651
#
#               salary: additional_salary_information:
# count           66688                          35044
# unique          10442                          11855
# top     Not specified                    Competitive
# freq            24013                           5626

# %%
df.isnull()
# Out:
#        job_type  job_name  posting_date:  hours:  closing_date:  location:
# 0         False     False          False   False          False      False  \
# 1         False     False          False   False          False      False
# 2         False     False          False   False          False      False
# 3         False     False          False   False          False      False
# 4         False     False          False   False          False      False
# ...         ...       ...            ...     ...            ...        ...
# 77766     False     False          False   False          False      False
# 77767     False     False          False   False          False      False
# 77768     False     False          False   False          False      False
# 77769     False     False          False   False          False      False
# 77770     False     False          False   False          False      False
#
#        company:  job_type:  job_reference:  salary:
# ...
