# %%
import pandas as pd

# %%
df = pd.read_json('./test.json')
df
# Out:
#                    job_type
# 0    Creative & Design Jobs  \
# 1             Graduate Jobs
# 2             Graduate Jobs
# 3    Energy, Oil & Gas Jobs
# 4    Energy, Oil & Gas Jobs
# ..                      ...
# 195        Social Care Jobs
# 196        Social Care Jobs
# 197        Social Care Jobs
# 198        Social Care Jobs
# 199        Social Care Jobs
#
#                                               job_name posting_date:
# 0                                          Night Nurse   22 May 2023  \
# 1    Graduate Engineering Business Development Exec...   17 May 2023
# 2                  GRADUATE LEARNING SUPPORT ASSISTANT   17 May 2023
# 3    Fulfilment Shift Leader UFC Replenishment - Co...   22 May 2023
# 4    Tesco Shift Leader - Days - Exmouth Churchill ...   22 May 2023
# ..                                                 ...           ...
# 195                              Care Assistant - Bank   22 May 2023
# ...

# %%
df.describe()
# Out:
#                       job_type                job_name posting_date:
# count                      200                     200           200  \
# unique                       8                     148             2
# top     Customer Services Jobs  Control Room Operative   22 May 2023
# freq                        50                      11           198
#
#               salary:     hours: closing_date: location:       company:
# count             180        200           200       200            200  \
# unique             88          2            20       175             99
# top     Not specified  Full time  21 June 2023  NR11 6YA  Runwood Homes
# freq               60        152           114         3             23
#
#         job_type: job_reference: additional_salary_information:
# count         200            200                            113
# unique          4            169                             68
# top     Permanent                                   Competitive
# ...

# %%
df.isnull()
# Out:
#      job_type  job_name  posting_date:  salary:  hours:  closing_date:
# 0       False     False          False    False   False          False  \
# 1       False     False          False    False   False          False
# 2       False     False          False    False   False          False
# 3       False     False          False    False   False          False
# 4       False     False          False    False   False          False
# ..        ...       ...            ...      ...     ...            ...
# 195     False     False          False    False   False          False
# 196     False     False          False    False   False          False
# 197     False     False          False    False   False          False
# 198     False     False          False    False   False          False
# 199     False     False          False    False   False          False
#
#      location:  company:  job_type:  job_reference:
# 0        False     False      False           False  \
# ...
