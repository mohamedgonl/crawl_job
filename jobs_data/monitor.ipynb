# %%
import pandas as pd

# %%
df = pd.read_json('./data.json')
df.rename(columns={'job_type:': 'duration'}, inplace= True)
df = df.rename(columns= (lambda x:  x.replace(':','')) )
df.head(10)
# Out:
#                                job_type
# 0  Agriculture, Fishing & Forestry Jobs  \
# 1      PR, Advertising & Marketing Jobs
# 2      PR, Advertising & Marketing Jobs
# 3      PR, Advertising & Marketing Jobs
# 4      PR, Advertising & Marketing Jobs
# 5      PR, Advertising & Marketing Jobs
# 6                         Property Jobs
# 7                  Scientific & QA Jobs
# 8                  Scientific & QA Jobs
# 9                  Scientific & QA Jobs
#
#                                             job_name posting_date      hours
# 0                      Harvest Temp - Site Operative  19 May 2023  Full time  \
# 1                    FIELD MARKETING – SELF EMPLOYED  22 May 2023  Full time
# 2                    FIELD MARKETING – SELF EMPLOYED  22 May 2023  Full time
# 3                    FIELD MARKETING – SELF EMPLOYED  22 May 2023  Full time
# 4                    FIELD MARKETING – SELF EMPLOYED  22 May 2023  Full time
# ...

# %%
df.describe()
# Out:
#                   job_type        job_name posting_date      hours
# count                77771           77771        77771      77771  \
# unique                  25           37606           31          2
# top     Other/General Jobs  Support Worker  12 May 2023  Full time
# freq                 14735            1071         5948      58799
#
#        closing_date    location   company   duration job_reference
# count         77771       77771     77771      77771         77771  \
# unique           60       33587      4207          4         65846
# top     26 May 2023  London, UK  NHS Jobs  Permanent
# freq           4393         308      7464      56904          9651
#
#                salary additional_salary_information
# count           66688                         35044
# unique          10442                         11855
# top     Not specified                   Competitive
# freq            24013                          5626

# %%
df['hours'].unique()
# Out:
# array(['Full time', 'Part time'], dtype=object)
